# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
csv_data = "../ETL/miami_df_final.csv"
miami_df = pd.read_csv(csv_data)

# %%
miami_df
# Out:
#         id             datetime   neighborhood  rent  br   ba    sqft  \
# 0        1  2021-05-30 14:02:00       Dadeland  1900   2  2.0     NaN
# 1        2  2021-05-30 14:02:00          Doral  2557   2  2.0     NaN
# 2        3  2021-05-30 14:02:00          Miami  2241   2  2.0  1106.0
# 3        4  2021-05-30 14:02:00          Doral  3399   3  2.0     NaN
# 4        5  2021-05-30 14:01:00          Doral  1978   1  1.0     NaN
# ...    ...                  ...            ...   ...  ..  ...     ...
# 1831  2590  2021-05-27 16:02:00          Miami  1950   1  1.0     NaN
# 1832  2593  2021-05-27 15:58:00    Miami Beach  2500   2  2.0  1300.0
# 1833  2597  2021-05-27 15:54:00        Kendall  1500   2  2.0     NaN
# 1834  2598  2021-05-27 15:54:00  Fontainebleau  1700   2  2.5     NaN
# 1835  2599  2021-05-27 15:54:00        Kendall  1850   2  2.0     NaN
#
#      housingType      laundry             parking cats dogs furnished  \
# 0      apartment  w/d in unit             carport   no   no        no
# 1      apartment  w/d in unit     attached garage   no   no        no
# 2      apartment  w/d in unit  off-street parking  yes  yes        no
# 3      apartment  w/d in unit     attached garage   no   no        no
# 4      apartment  w/d in unit     attached garage   no   no        no
# ...          ...          ...                 ...  ...  ...       ...
# 1831   apartment  w/d in unit             carport   no   no        no
# 1832   apartment  w/d in unit             carport   no   no        no
# 1833   apartment  w/d in unit             carport   no   no        no
# 1834   apartment  w/d in unit             carport   no   no        no
# 1835   apartment  w/d in unit             carport   no   no        no
#
#                                                   title  \
# 0     2/2 DADELAND: AMAZING UNIT Unique opportunity ...
# 1                                     DEPÓSITO DE $ 500
# 2                            2 Bed 2 Bathroom Apartment
# 3     $500 deposit one,two,and three bedroom 24 hour...
# 4                                         un mes GRATIS
# ...                                                 ...
# 1831   Low credit or bad credit. NO PROBLEM BEST DEA...
# 1832                  SHORT TERM RENTAL APT BAL HARBOUR
# 1833  2/2 2 Bedroom 2 Bathroom Unit Available KENDAL...
# 1834  2/2.5 FONTAINEBLEU: MAGNIFICENT UNIT Great Loc...
# 1835  2/2 BEST DEAL ON THIS UNIT Huge 1,050 square f...
#
#                                             description  \
# 0     80DADELAND: 2/2Unique opportunity to lease thi...
# 1     *** UNFURNISHED ONE,TWO,AND THREE BEDROOM ****...
# 2     One, Two, and Three Bedroom Miami Apartments A...
# 3     *** UNFURNISHED ONE,TWO,AND THREE BEDROOM ****...
# 4     *** UNFURNISHED ONE,TWO,AND THREE BEDROOM ****...
# ...                                                 ...
# 1831  0Gorgeous apartments ready to move in immediat...
# 1832  Gorgeous apartment in Bal Harbour Miami Beach....
# 1833  04KENDALL: 2/22 Bedroom 2 Bathroom Unit Availa...
# 1834  09FONTAINEBLEU: 2/2.5Great Location, beautiful...
# 1835  61KENDALL: 2/2Huge 1,050 square foot 2 bedroom...
#
#                                                    link
# 0     https://miami.craigslist.org/mdc/apa/d/2-dadel...
# 1     https://miami.craigslist.org/mdc/apa/d/miami-d...
# 2     https://miami.craigslist.org/mdc/apa/d/miami-b...
# 3     https://miami.craigslist.org/mdc/apa/d/miami-5...
# 4     https://miami.craigslist.org/mdc/apa/d/miami-u...
# ...                                                 ...
# 1831  https://miami.craigslist.org/mdc/apa/d/miami-l...
# 1832  https://miami.craigslist.org/mdc/apa/d/miami-b...
# 1833  https://miami.craigslist.org/mdc/apa/d/bedroom...
# 1834  https://miami.craigslist.org/mdc/apa/d/fontain...
# 1835  https://miami.craigslist.org/mdc/apa/d/2-best-...
#
# [1836 rows x 16 columns]

# %%
# Assign the data to X and y

X = brains["weight"].values.reshape(-1, 1)
y = brains["size"].values.reshape(-1, 1)

print("Shape: ", X.shape, y.shape)

# %% [markdown]
# ## LOGISTIC REGRESSION
# Run LR model

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LogisticRegression
